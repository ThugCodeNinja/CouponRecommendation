# %%
# @title
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# Generate sample data
# np.random.seed(42)

transaction_ids = np.random.randint(2000, 2100, 100)
transaction_dates = [datetime.now() - timedelta(days=np.random.randint(0, 30)) for _ in range(100)]
categories = np.random.choice(['groceries', 'electronics', 'entertainment', 'clothing'], 100)
amounts = np.round(np.random.uniform(10, 500, 100), 2)
user_ages = np.random.randint(18, 70, 100)
user_genders = np.random.choice(['male', 'female','other'], 100)
user_locations = np.random.choice(['Mumbai','Hyderabad','Chennai','New Delhi','Jaipur'], 100)

# Create DataFrame
df = pd.DataFrame({
    'TransactionID': transaction_ids,
    'TransactionDate': transaction_dates,
    'Category': categories,
    'Amount': amounts,
    'UserAge': user_ages,
    'UserGender': user_genders,
    'UserLocation': user_locations
})

# Display the first few rows
print(df.head())
# Out:
#    TransactionID            TransactionDate       Category  Amount  UserAge  \
# 0           2078 2024-07-11 02:29:46.769095    electronics  100.12       43
# 1           2095 2024-07-08 02:29:46.769128      groceries  260.71       27
# 2           2086 2024-07-15 02:29:46.769137  entertainment  211.70       20
# 3           2094 2024-07-15 02:29:46.769143      groceries  458.92       55
# 4           2052 2024-07-24 02:29:46.769148       clothing  145.20       33
#
#   UserGender UserLocation
# 0      other       Jaipur
# 1      other    Hyderabad
# 2       male       Mumbai
# 3       male    Hyderabad
# 4       male    Hyderabad

# %%
# !pip install langchain_community sentence_transformers langchain_groq langchain_groq langchain_text_splitters faiss-cpu langchainhub
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.0/27.0 MB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.3/990.3 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.2/374.2 kB 18.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 15.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.5/103.5 kB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 14.2 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...

# %%
with (open('file.txt','w') as f):
  f.write('''
  1. Get 20% off on electronics at Croma, Delhi with code ELECTRODEL20.
2. Enjoy 15% off on clothing at Lifestyle, Chennai using code LIFESTYLECHN15.
3. Save 10% on groceries at Big Bazaar, Mumbai with code BAZAARMUM10.
4. Get 25% off on furniture at Home Centre, Hyderabad using code HOMEHYD25.
5. Avail 30% discount on electronics at Reliance Digital, Jaipur with code RELDIGJAI30.
6. Enjoy 20% off on men's clothing at Westside, Delhi with code WESTDEL20.
7. Save 15% on fresh vegetables at Reliance Fresh, Chennai using code FRESHCHN15.
8. Get 10% off on dining tables at Pepperfry, Mumbai with code PEPPER10.
9. Avail 20% discount on mobile phones at Vijay Sales, Hyderabad using code VIJAYHYD20.
10. Enjoy 25% off on women's clothing at Pantaloons, Jaipur with code PANTJAI25.
11. Get 15% off on groceries at D-Mart, Delhi with code DMARTDEL15.
12. Save 10% on electronics at Samsung Store, Chennai with code SAMCHN10.
13. Avail 30% discount on sofas at Urban Ladder, Mumbai using code URBANMUM30.
14. Enjoy 20% off on clothing at Max Fashion, Hyderabad with code MAXHYD20.
15. Get 25% off on kitchen appliances at HomeStop, Jaipur with code HOMESTOPJAI25.
16. Save 15% on groceries at Food Hall, Delhi with code FOODDEL15.
17. Get 10% off on laptops at Lenovo Store, Chennai using code LENOVOCHN10.
18. Avail 20% discount on beds at Nilkamal, Mumbai with code NILKMUM20.
19. Enjoy 25% off on men's footwear at Bata, Hyderabad using code BATAHYD25.
20. Get 15% off on fresh fruits at Spencer's, Jaipur with code SPENJAI15.
21. Save 10% on home decor at IKEA, Delhi using code IKEADEL10.
22. Avail 30% discount on LED TVs at Sony Center, Chennai with code SONYCHN30.
65. Save 15% on dining sets at HomeStop, Jaipur with code HOMESTOPJAI15.
66. Get 10% off on electronics at Vijay Sales, Delhi with code VIJAYDEL10.
67. Avail 20% discount on kitchen appliances at Wonderchef, Chennai with code WONDERCHN20.
68. Enjoy 25% off on men's footwear at Bata, Mumbai with code BATAMUM25.
69. Get 15% off on fresh fruits at Spencer's, Hyderabad with code SPENHYD15.
70. Save 10% on home decor at FabIndia, Jaipur with code FABJAI10.
71. Avail 30% discount on mobile phones at Apple Store, Delhi using code APPLEDEL30.
72. Enjoy 20% off on women's footwear at Mochi, Chennai with code MOCHICHN20.
73. Get 25% off on living room furniture at Durian, Mumbai with code DURIANMUM25.
74. Save 15% on fresh dairy products at Heritage, Hyderabad with code HERITHYD15.
75. Get 10% off on electronics at Sony Center, Jaipur with code SONYJAI10.
76. Avail 20% discount on men's accessories at Van Heusen, Delhi using code VANDEL20.
77. Enjoy 25% off on groceries at Easyday, Chennai with code EASYCHN25.
78. Get 15% off on home lighting at Philips, Mumbai using code PHILIPSMUM15.
79. Save 10% on women's jewelry at Tanishq, Hyderabad with code TANHYD10.
80. Avail 20% discount on men's shirts at Arrow, Jaipur using code ARROWJAI20.
81. Enjoy 25% off on kitchen gadgets at Prestige, Delhi with code PRESTDEL25.
82. Get 15% off on groceries at More, Chennai with code MORECHN15.
83. Save 10% on electronics at Panasonic Store, Mumbai using code PANSOMUM10.
84. Avail 30% discount on air conditioners at Blue Star, Hyderabad using code BLUESTARHYD30.
85. Enjoy 20% off on men's jeans at Levis, Jaipur with code LEVISJAI20.
86. Get 25% off on fresh produce at Nature's Basket, Delhi with code NATUREDEL25.
87. Save 15% on mobile accessories at Croma, Chennai using code CROMACHN15.
88. Get 10% off on furniture at Urban Ladder, Mumbai with code URBANMUM10.
89. Avail 20% discount on sports shoes at Nike, Hyderabad with code NIKEHYD20.
90. Enjoy 25% off on grocery shopping at Spar, Jaipur with code SPARJAI25.
91. Get 15% off on electronics at LG Store, Delhi with code LGDEL15.
92. Save 10% on dining tables at Pepperfry,Chennai with code PEPPERCHN10.
93. Avail 30% discount on refrigerators at Panasonic Store, Mumbai using code PANMUM30.
94. Enjoy 20% off on men's watches at Titan, Hyderabad with code TITANHYD20.
95. Get 25% off on fresh vegetables at Reliance Fresh, Jaipur with code FRESHJAI25.
96. Save 15% on clothing at Westside, Delhi with code WESTDEL15.
97. Get 10% off on electronics at Samsung Store, Chennai using code SAMCHN10.
98. Avail 20% discount on living room furniture at Nilkamal, Mumbai with code NILKMUM20.
99. Enjoy 25% off on groceries at D-Mart, Hyderabad with code DMARTHYD25.
100. Get 15% off on home appliances at Home Centre, Jaipur with code HOMEJAI15.
  ''')

# %%
import os
import langchain
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.document_loaders import TextLoader
text_splitter = RecursiveCharacterTextSplitter(chunk_size=150, chunk_overlap=0, separators=["\n",'.  '])
loader = TextLoader('file.txt')
docs = loader.load()
split_docs = text_splitter.split_documents(docs)

# %%
# from langchain_chroma import Chroma
# from langchain.vectorstores import Chroma
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceBgeEmbeddings
from langchain.schema import Document
# Iterate over the Document objects and extract the content and metadata using the appropriate attributes
split_docss = [Document(page_content=t.page_content, metadata=t.metadata) for t in split_docs]
embeddings = HuggingFaceBgeEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
vectorstore = FAISS.from_documents(split_docss,embeddings)
# Out:
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# ...

# %%
os.environ['GROQ_API_KEY']='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'

# %%
#just vector retrieval check

retriever=vectorstore.as_retriever()
retriever.search_kwargs['k'] = 3
response=retriever.get_relevant_documents(query="Electronics in chennai ")
for i in response:
  print(i.page_content)
# Out:
# 97. Get 10% off on electronics at Samsung Store, Chennai using code SAMCHN10.
# 12. Save 10% on electronics at Samsung Store, Chennai with code SAMCHN10.
# 66. Get 10% off on electronics at Vijay Sales, Delhi with code VIJAYDEL10.

# %%
"mixtral-8x7b-32768"
# Out:
# 'mixtral-8x7b-32768'

# %%
from langchain_groq import ChatGroq
from langchain.text_splitter import CharacterTextSplitter
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain.schema.runnable import RunnablePassthrough
from langchain_core.runnables import Runnable
from langchain.retrievers import EnsembleRetriever,BM25Retriever
def preprocess(text):
  return "\\n".join(x.page_content for x in text)
def format_docs(docs):
  return "\n".join(doc.page_content for doc in docs)
def printer(text):
  print(text)
  return text
retriever=vectorstore.as_retriever()
retriever.search_kwargs['k'] = 10
llm = ChatGroq(temperature=0, model_name="mixtral-8x7b-32768", streaming=True, verbose=False)
# llama3-8b-8192
prompt='''You are a coupon recommender chatbot.
Understand the question with the category of the item and the location:
{summary}
and answer with only relevant coupons:
{context}

Instructions:
List only the coupons that match the category of the item along with the location in the question.Use three sentences maximum and keep the answer concise.
 '''
template=PromptTemplate(template=prompt,input_variables=['summary','context'])
rag_chain=({ "summary": RunnablePassthrough(), "context": retriever | format_docs ,
             } | template|printer| llm| StrOutputParser())
query = "electronics in chennai"
response=rag_chain.invoke(query)
print(response)
# Out:
# text='You are a coupon recommender chatbot.\nUnderstand the question with the category of the item and the location:\nelectronics in chennai\nand answer with only relevant coupons:\n97. Get 10% off on electronics at Samsung Store, Chennai using code SAMCHN10.\n12. Save 10% on electronics at Samsung Store, Chennai with code SAMCHN10.\n66. Get 10% off on electronics at Vijay Sales, Delhi with code VIJAYDEL10.\n1. Get 20% off on electronics at Croma, Delhi with code ELECTRODEL20.\n2. Enjoy 15% off on clothing at Lifestyle, Chennai using code LIFESTYLECHN15.\n43. Save 10% on electronics at Panasonic Store, Mumbai using code PANSOMUM10.\n83. Save 10% on electronics at Panasonic Store, Mumbai using code PANSOMUM10.\n5. Avail 30% discount on electronics at Reliance Digital, Jaipur with code RELDIGJAI30.\n56. Save 15% on clothing at Pantaloons, Delhi with code PANTDEL15.\n57. Get 10% off on electronics at Samsung Store, Chennai using code SAMCHN10.\n62. Avail 30% discount on LED TVs at Relia
# ...

# %%
from langchain import hub
text=hub.pull("rlm/rag-prompt")

# %%
print(text)
# Out:
# input_variables=['context', 'question'] metadata={'lc_hub_owner': 'rlm', 'lc_hub_repo': 'rag-prompt', 'lc_hub_commit_hash': '50442af133e61576e74536c6556cefe1fac147cad032f4377b60c436e6cdcb6e'} messages=[HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['context', 'question'], template="You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know. Use three sentences maximum and keep the answer concise.\nQuestion: {question} \nContext: {context} \nAnswer:"))]
